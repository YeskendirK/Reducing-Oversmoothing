# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nlayers = [2,3,4,5,6,7,8,9,10,12,16,20, 24,28,32]

# %%
baseline_val_acc = [0.81, 0.808, 0.814, 0.8, 0.796, 0.79, 0.792, 0.768, 0.59, 0.182, 0.318, 0.206, 0.224, 0.236, 0.368]

# %%
random_val = [0.3] * len(nlayers)

# %%
plt.plot(nlayers, baseline_val_acc, label='basline')
plt.plot(nlayers, random_val)
plt.title("DeepGAT val. acc.")
plt.show()
